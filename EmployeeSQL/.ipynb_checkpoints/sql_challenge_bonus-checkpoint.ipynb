# %%
# %matplotlib inline

import pandas as pd
import psycopg2
import sqlalchemy
import matplotlib as plt
import numpy as np
import matplotlib.pyplot as plt
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func
from sqlalchemy import Column, Float, Integer, String, Date
from sqlalchemy.ext.declarative import declarative_base
Base2 = declarative_base()

# %%
conn = psycopg2.connect("dbname=sql_challenge user=postgres password=R31n33nj! host=localhost")

# %%
cur = conn.cursor()

# %%
#2. Create a histogram to visualize the most common salary ranges for employees.
cur.execute("SELECT salary, count(salary) FROM salaries GROUP BY salary ORDER BY count(salary) DESC")
rows = cur.fetchall()
rows
# Out:
# [(40000, 95346),
#  (55581, 19),
#  (53078, 18),
#  (53738, 18),
#  (47454, 17),
#  (44564, 17),
#  (45184, 17),
#  (43995, 16),
#  (47038, 16),
#  (49416, 16),
#  (43710, 16),
#  (51499, 16),
#  (45050, 16),
#  (53783, 16),
#  (44780, 15),
#  (50650, 15),
#  (50368, 15),
#  (46559, 15),
#  (50675, 15),
#  (43944, 15),
#  (45211, 15),
#  (46310, 15),
#  (53876, 15),
#  (50952, 15),
#  (58583, 15),
#  (57425, 15),
#  (47460, 15),
#  (50109, 15),
#  (44355, 15),
#  (52660, 15),
#  (54108, 15),
#  (50493, 15),
#  (41767, 15),
#  (49007, 15),
#  (42291, 15),
#  (50431, 15),
#  (45294, 15),
#  (43726, 15),
#  (42088, 15),
#  (49357, 15),
#  (52550, 15),
#  (48250, 15),
#  (53303, 14),
#  (42108, 14),
#  (48402, 14),
#  (48068, 14),
#  (52908, 14),
#  (51421, 14),
#  (44382, 14),
#  (48624, 14),
#  (42382, 14),
#  (40954, 14),
#  (49056, 14),
#  (49234, 14),
#  (44728, 14),
#  (47079, 14),
#  (55650, 14),
#  (49232, 14),
#  (43632, 14),
#  (49350, 14),
#  (50016, 14),
#  (46452, 14),
# ...

# %%
#3. Create a bar chart of average salary by title.
cur.execute("SELECT DISTINCT title FROM titles")
title_lable = cur.fetchall()
title_lable
# Out:
# [('Engineer',),
#  ('Senior Engineer',),
#  ('Manager',),
#  ('Assistant Engineer',),
#  ('Staff',),
#  ('Senior Staff',),
#  ('Technique Leader',)]

# %%
cur.execute("SELECT title, count(title) FROM titles GROUP BY title ORDER BY count(title) DESC")
title_cnt = cur.fetchall()
title_cnt
# Out:
# [('Engineer', 115003),
#  ('Staff', 107391),
#  ('Senior Engineer', 97750),
#  ('Senior Staff', 92853),
#  ('Technique Leader', 15159),
#  ('Assistant Engineer', 15128),
#  ('Manager', 24)]

# %%
labels = ['Engineer', 'Senior Engineer', 'Manager', 'Assistant Engineer', 'Staff', 'Senior Staff', 'Technique Leader']
x_axis = np.arange(len(title_cnt))

# %%
plt.bar(x_axis, labels, color='r', alpha=0.5, align="center")
# Out:
# <BarContainer object of 7 artists>
